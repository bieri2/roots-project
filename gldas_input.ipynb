# %%
# %run process_gldas.ipynb
import os
import matplotlib.pyplot as plt

# %%
# Define paths
path_to_gldas_files = '/data/keeling/a/bieri2/b/GLDAS_raw/data/'
out_location  = '/data/keeling/a/bieri2/b/NoahMP_2D/LDASIN_files/'
wrfinput_file = '/data/keeling/a/bieri2/b/GLDAS_raw/geogrid/wrfinput_d01_2018.01.01.00'

# Get list of GLDAS files
files = sorted(os.listdir(path_to_gldas_files))

# %%
# Open and call process() method for each file
for file in files:
    print('Processing ' + file)
    gldas_data = gldas(path_to_gldas_files + file)
    
    # Create initialization file if processing first time step
    if file == files[0]:
        regridded = gldas_data.process(out_location, wrfinput_file, t0 = True)
    # Clear regrid file if processing the last file
    elif file == [-1]:
        regridded = gldas_data.process(out_location, wrfinput_file, clear_weight_file = True)
    else:
        regridded = gldas_data.process(out_location, wrfinput_file)
# Out:
# Processing GLDAS_NOAH025_3H.A20180101.0000.021.nc4.SUB.nc4
# Reuse existing file: bilinear_304x304_749x699.nc
# using dimensions ('lat', 'lon') from data variable Wind_f_inst as the horizontal dimensions for this dataset.
# Created file 2018010100.LDASIN_DOMAIN1
# Processing GLDAS_NOAH025_3H.A20180101.0300.021.nc4.SUB.nc4
# Reuse existing file: bilinear_304x304_749x699.nc
# using dimensions ('lat', 'lon') from data variable Wind_f_inst as the horizontal dimensions for this dataset.
# Created file 2018010103.LDASIN_DOMAIN1
# Processing GLDAS_NOAH025_3H.A20180101.0600.021.nc4.SUB.nc4
# Reuse existing file: bilinear_304x304_749x699.nc
# using dimensions ('lat', 'lon') from data variable Wind_f_inst as the horizontal dimensions for this dataset.
# Created file 2018010106.LDASIN_DOMAIN1
# Processing GLDAS_NOAH025_3H.A20180101.0900.021.nc4.SUB.nc4
# Reuse existing file: bilinear_304x304_749x699.nc
# ...
